# %% [markdown]
# # **Python Object Oriented Programming (OOP) - Full Course for Beginners**

# %%
name = "Khan"
age = 29

print(name.upper())
# Out:
# KHAN

# %%
class Dog:
    def __init__(self, name, breed, owner):
        self.name = name
        self.breed = breed
        self.owner = owner
        
    
    def super():
        print("Bark.")
    
    def bark(self):
        print("Whoof Whoof")
    pass


class Owner:
    def __init__(self, name, address, contact):
        self.name = name
        self.address = address
        self.phone_no = contact
        
        
owner1 = Owner("Khan", "Unknown", "0353546513") 
owner2 = Owner("ASD", "Unknown", "54564564564") 


dog = Dog("Bruce", "IDK", owner1)
dog.bark()
print(dog.owner.name)
print(dog.name)
print(dog.breed)

dog2 = Dog("NEw", "ISK", owner2)
dog2.bark()
print(dog2.name)
print(dog2.breed)
print(dog2.owner.name)
# Out:
# Whoof Whoof
# Khan
# Bruce
# IDK
# Whoof Whoof
# NEw
# ISK
# ASD

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        pass
    
    def greet(self):
        print(f"Hello, My name is {self.name} and I'm {self.age} year old.")
            
        pass
    

def main():
    p1 = Person("Khan", 56)
    p1.greet()
    p2 = Person("Boob", 556)
    p2.greet()
    

if __name__ == '__main__':
    main()
# Out:
# Hello, My name is Khan and I'm 56 year old.
# Hello, My name is Boob and I'm 556 year old.

# %%
from datetime import datetime

class User:
    def __init__(self, username, email, password):
        self.username = username
        self.__email = email
        self.password = password
        
    def greet(self, user):
        print(f"Sending message to {user.username}: Hi {user.username}, its {self.username}")
    
    def get_email(self):
        return self.__email
    
    def clean_eamil(self):
        return self.__email.lower().strip() 
    
    def set_email(self, new_email):
        if "@" in new_email:
            print(f"Email access at {datetime.now()}")
            self.__email = new_email
      
def main():
    user1 = User("Khan", "SDASDASD@gmial.com", "123")
    user2 = User("Kasdasd", "asdsa@gmial.com", "34")
    
    user1.greet(user2)
    
    user1.email = "sadasdasd@dsfdshf"
    print(user1.get_email())
    print(user1.email)
    print(user1.clean_eamil())
    print(user1.get_email())
    
    
    user1.set_email("kjsadjkahs@gmail.com")
    print(user1.get_email())
    
if __name__ == '__main__':
    main()
# Out:
# Sending message to Kasdasd: Hi Kasdasd, its Khan
# SDASDASD@gmial.com
# sadasdasd@dsfdshf
# sdasdasd@gmial.com
# SDASDASD@gmial.com
# Email access at 2026-04-29 01:16:43.974686
# kjsadjkahs@gmail.com

# %%
class User:
    def __init__(self, username, email, password):
        self.username = username
        self._email = email
        self.password = password
        
    @property
    def email(self):
        print("Email Accessed.")
        return self._email

    @email.setter
    def email(self, new_email):
        if "@" not in new_email:
            raise ValueError("Email is not correct.")
        self._email = new_email
        
def main():
    
    user1 = User("Khan", "khan@gmail.com", 123)
    # user1.email = "Thisisnotanemailnewemail" # Check it
    print(user1.email)
    

if __name__ == "__main__":
    main()
# Out:
# Email Accessed.
# khan@gmail.com

# %% [markdown]
# ## **Static Attributes**

# %%
class User:
    user_count = 0
    
    def __init__(self, username, email, password):
        self.username = username
        self._email = email
        self.password = password
        User.user_count += 1
        
    def display_user(self):
        print(f"UserName: {self.username}, Email: {self._email}")
        

def main():

    user1 = User("khan", "easdkjl@asdj", "123")
    user2 = User("asdasd", "ssssss@ggg", "6546")
    
    print(f"Total Users are: {User.user_count}")


if __name__ == "__main__":
    main()
# Out:
# Total Users are: 2

# %% [markdown]
# ### **Static vs Instance Method Example:**

# %%
class BankAccount:
    MIN_BALANCE = 100
    
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self._balance = balance
    
    def deposit(self, amount):
        if self._is_valid_amount(amount):
            self._balance += amount
            print(f"{self.owner}'s new balance: ${self._balance} ")
            self.__log_transcation("deposit", amount)
        else:
            print("Deposit amount must be positive.")  
     
    @staticmethod       
    def is_valid_interest_rate(rate):
        return 0 <= rate <= 5
    
    def _is_valid_amount(self, amount):
        return amount > 0
    
    def __log_transcation(self, transcation_type, amount):
        print(f"Logging {transcation_type} of ${amount}. New balance: ${self._balance}")

        
def main():
    account = BankAccount("Khan", 500)
    account.deposit(200)
    
    # account
    print(BankAccount.is_valid_interest_rate(3))
    print(BankAccount.is_valid_interest_rate(10))
    print(BankAccount.is_valid_interest_rate(5))
    
    account._is_valid_amount(200)
    # account.__log_transcation("withdraw",200)
    
    pass
    
if __name__ == "__main__":
    main()
# Out:
# Khan's new balance: $700
# Logging deposit of $200. New balance: $700
# True
# False
# True

# %% [markdown]
# # **Encapsulation:**

# %%
class BadBankAccount:
    def __init__(self, balance):
        self.balance = balance
    
    
class BankAccount:
    def __init__(self):
        self._balance = 0.0
    
    @property
    def balance(self):
        return self._balance
    
    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")
        self._balance += amount
        
    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdraw amount must be positive")
        elif amount >= self._balance:
            raise ValueError("Insufficient funds")
        self._balance -= amount
        
    
def main():
    
    account = BadBankAccount(0)

    account.balance = -1
    
    acc1 = BankAccount()
    print(acc1.balance)
    
    acc1.deposit(19021)
    print(acc1.balance)

    acc1.withdraw(19020)
    print(acc1.balance)
    
    
    pass
    
if __name__ == "__main__":
    main()
# Out:
# 0.0
# 19021.0
# 1.0

# %% [markdown]
# # **Abstraction:**

# %%
class EmailService:
    
    def __init__(self):
        pass
    
    def _connect(self):
        print("Connecting to email server.")
        
    def _authenticating(self):
        print("Authenticating ...")
        
    def _disconnect(self):
        print("Disconnecting from email server.")
    
    def send_email(self):
        self._connect()
        self._authenticating()
        print("Sending email ...")
        self._disconnect()
        
            
def main():
    email = EmailService()
    email.send_email()
        
if __name__ == "__main__":
    main()
# Out:
# Connecting to email server.
# Authenticating ...
# Sending email ...
# Disconnecting from email server.

# %% [markdown]
# # **Inheritance**

# %% [markdown]
# ## **🔹 1. Single Inheritance**

# %%
class Vehicle:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def start(self):
        print("Vehicle is starting.")
    
    def stop(self):
        print("Vehicle is stoping")
 
class Car(Vehicle):
    def __init__(self, brand, model, year, number_of_doors,number_of_wheels):
        
        super().__init__(brand, model, year) # its like list initialization in C++
        self.number_of_doors = number_of_doors
        self.number_of_wheels = number_of_wheels

class Bike(Vehicle):
    def __init__(self, brand, model, year, number_of_wheels):
        
        super().__init__(brand, model, year)
        self.number_of_wheels = number_of_wheels   

def main():
    
    car = Car("Ford", "Focus", 2008, 5, 4)
    bike = Bike("Honda", "Scoopy", 2018, 2)
    # print(car.__dict__, "\n\n")
    
    car.start()
    bike.start()



if __name__ == "__main__":
    main()
# Out:
# Vehicle is starting.
# Vehicle is starting.

# %% [markdown]
# ## **🔹 2. Multiple Inheritance**

# %%
# class Father:
#     def __init__(self, f_name):
#         self.f_name = f_name
        
#     def intro(self):
#         print("I m his Father.")

# class Mother:
#     def __init__(self, m_name):
#         self.m_name = m_name
    
#     def intro(self):
#         print("I m his Mother.")
        
    
# class Child(Father, Mother):
#     def __init__(self, name, age, f_name, m_name):
#         Father.__init__(self, f_name)
#         Mother.__init__(self, m_name)
#         self.name = name
#         self.age = age

class Father:
    def __init__(self, f_name, **kwargs):
        super().__init__(**kwargs)
        self.f_name = f_name

    def intro(self):
        print("I m his Father.")

class Mother:
    def __init__(self, m_name, **kwargs):
        super().__init__(**kwargs)
        self.m_name = m_name
    
    def intro(self):
        print("I m his Mother.")
        

class Child(Father, Mother):
    def __init__(self, name, age, f_name, m_name):
        super().__init__(f_name=f_name, m_name=m_name)
        self.name = name
        self.age = age

def main():
    c1 = Child("Khan", 52, "AAA", "BBB")
    # c1.intro()
    # print(Child.__mro__)
    
    print(c1.name)
    print(c1.age)
    print(c1.f_name)
    print(c1.m_name)
    
    
    pass

if __name__ == "__main__":
    main()
# Out:
# Khan
# 52
# AAA
# BBB

# %% [markdown]
# ## **🔹 3. Multilevel Inheritance**

# %%
# for Now we dont need daimond problem.
class Grandparent:
    def __init__(self, g_name, **kwargs):
        
        super().__init__(**kwargs)
        self.g_name = g_name
        
class Father(Grandparent):
    def __init__(self, f_name, **kwargs):
        
        super().__init__(**kwargs)
        self.f_name = f_name

    def intro(self):
        print("I m his Father.")

class Mother:
    def __init__(self, m_name, **kwargs):
        
        super().__init__(**kwargs)
        self.m_name = m_name
    
    def intro(self):
        print("I m his Mother.")
        

class Child(Father, Mother):
    def __init__(self, name, age, f_name, m_name, g_name):
        super().__init__(f_name=f_name, m_name=m_name, g_name=g_name)
        self.name = name
        self.age = age

def main():
    c1 = Child("Khan", 52, "AAA", "BBB","FFF")
    # c1.intro()
    # print(Child.__mro__)
    
    # print(c1.name)
    # print(c1.age)
    # print(c1.f_name)
    # print(c1.m_name)
    
    print(Child.__mro__)
    
    
    pass

if __name__ == "__main__":
    main()
# Out:
# (<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Grandparent'>, <class '__main__.Mother'>, <class 'object'>)

# %%
## **🔹 4. Hierarchical Inheritance**

# %%
# for Now we dont need daimond problem.
class Grandparent:
    def __init__(self, g_name, **kwargs):
        
        super().__init__(**kwargs)
        self.g_name = g_name
        
class Father(Grandparent):
    def __init__(self, f_name, **kwargs):
        
        super().__init__(**kwargs)
        self.f_name = f_name

    def intro(self):
        print("I m his Father.")

class Mother:
    def __init__(self, m_name, **kwargs):
        
        super().__init__(**kwargs)
        self.m_name = m_name
    
    def intro(self):
        print("I m his Mother.")
        

class Boy(Father, Mother):
    def __init__(self, name, age, f_name, m_name, g_name):
        super().__init__(f_name=f_name, m_name=m_name, g_name=g_name)
        self.name = name
        self.age = age
        
class Girl(Father, Mother):
    def __init__(self, name, age, f_name, m_name, g_name):
        super().__init__(f_name=f_name, m_name=m_name, g_name=g_name)
        self.name = name
        self.age = age

def main():
    c1 = Child("Khan", 52, "AAA", "BBB","FFF")
    
    print(c1.name)
    print(c1.age)
    print(c1.f_name)
    print(c1.m_name)
    print(Child.__mro__)
    
    c2 = Girl("GGGG", 5, "AAA", "BBB","FFF")
    
    print(c2.name)
    print(c2.age)
    print(c2.f_name)
    print(c2.m_name)
    print(Girl.__mro__)
    
    
    
    pass

if __name__ == "__main__":
    main()
# Out:
# Khan
# 52
# AAA
# BBB
# (<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Grandparent'>, <class '__main__.Mother'>, <class 'object'>)
# GGGG
# 5
# AAA
# BBB
# (<class '__main__.Girl'>, <class '__main__.Father'>, <class '__main__.Grandparent'>, <class '__main__.Mother'>, <class 'object'>)

# %% [markdown]
# ### **🔹 5. Hybrid Inheritance** -> **(Diamond Problem)**
#
# will cover after the Polymorphism.

# %% [markdown]
# ## **Polymorphism**

# %%
class Car():
    def __init__(self, brand, model, year, number_of_doors,number_of_wheels):
        self.brand = brand
        self.model = model
        self.year = year
        self.number_of_doors = number_of_doors
        self.number_of_wheels = number_of_wheels
        
    def start(self):
        print("Car is starting.")
    
    def stop(self):
        print("Car is stoping")

class Bike():
    def __init__(self, brand, model, year, number_of_wheels):
        self.brand = brand
        self.model = model
        self.year = year
        self.number_of_wheels = number_of_wheels
        
    def start(self):
        print("Bike is starting.")
    
    def stop(self):
        print("Bike is stoping")
           

def main():
    # Create list of vehicle to inspect
    vehicle = [
        Car("Ford", "Focus", 2008, 5, 4),
        Bike("Honda", "Scoopy", 2018, 2)
    ]
    
    # Loop through of the vehicles to inspect them
    for v in vehicle:
        if isinstance(v, Car):
            print(f"Inspecting {v.brand} {v.model} ({type(v).__name__})")
            v.start()
            v.stop()
        elif isinstance(v, Bike):
            print(f"Inspecting {v.brand} {v.model} ({type(v).__name__})")
            v.start()
            v.stop()
        else:
            raise Exception("Object is not Valid Vehicle.")
    

if __name__ == "__main__":
    main()
# Out:
# Inspecting Ford Focus (Car)
# Car is starting.
# Car is stoping
# Inspecting Honda Scoopy (Bike)
# Bike is starting.
# Bike is stoping

# %%
class Vehicle:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def start(self):
        print("Vehicle is starting.")
    
    def stop(self):
        print("Vehicle is stoping")
 
class Car(Vehicle):
    def __init__(self, brand, model, year, number_of_doors,number_of_wheels):
        
        super().__init__(brand, model, year) # its like list initialization in C++
        self.number_of_doors = number_of_doors
        self.number_of_wheels = number_of_wheels
        
    def start(self):
        print("Car is starting.")
    
    def stop(self):
        print("Car is stoping")

class Bike(Vehicle):
    def __init__(self, brand, model, year, number_of_wheels):
        
        super().__init__(brand, model, year)
        self.number_of_wheels = number_of_wheels
        
    def start(self):
        print("Bike is starting.")
    
    def stop(self):
        print("Bike is stoping")
           

def main():
    # Create list of vehicle to inspect
    vehicle: list[Vehicle] = [
        Car("Ford", "Focus", 2008, 5, 4),
        Bike("Honda", "Scoopy", 2018, 2)
    ]
    
    # Loop through of the vehicles to inspect them
    for v in vehicle:
        # if isinstance(v, Vehicle):
        print(f"Inspecting {v.brand} {v.model} ({type(v).__name__})")
        v.start()
        v.stop()

if __name__ == "__main__":
    main()
# Out:
# Inspecting Ford Focus (Car)
# Car is starting.
# Car is stoping
# Inspecting Honda Scoopy (Bike)
# Bike is starting.
# Bike is stoping
